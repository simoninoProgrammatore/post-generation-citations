# %% [markdown]
# # Data Exploration
#
# Explore the ALCE benchmark datasets and understand the data format.

# %%
import json
import pandas as pd
from pathlib import Path

# %%
# Load ASQA dataset
data_path = Path('../data/alce/asqa.json')  # adjust path as needed

if data_path.exists():
    with open(data_path) as f:
        data = json.load(f)
    print(f'Loaded {len(data)} examples')
    print(f'Keys per example: {list(data[0].keys())}')
else:
    print(f'Dataset not found at {data_path}')
    print('Run: bash scripts/download_data.sh')
